# %% [markdown]
# # Instalação Python/Jupyter
#
# Para instalar o python e o [jupyter notebook](https://www.continuum.io/downloads#linux) (ferramenta utilizada para escrever as aulas/exercícios), recomendamos usar o [anaconda](https://www.continuum.io/downloads#windows) que facilita a instalacao e configuraçao de python em [Linux](https://www.continuum.io/downloads#linux), [Windows](https://www.continuum.io/downloads#windows) e [Mac](https://www.continuum.io/downloads#mac), além de ter varios pacotes python datascience pré-instalados. Caso queiram instalar uma versão sem os pacotes de datascience podem faze-lo com o [miniconda](https://conda.io/miniconda.html)
#
# # Instalação dos Pacotes
#
# Instalado o python e o jupyter (via anaconda ou nao), temos que instalar os pacotes necessarios para as aulas. Para isso primeiro temos que abrir o jupyter notebook. Parto do príncipio que o jupyter já foi instalado (via anaconda ou via pip install jupyter senão).
#
# ## Windows
#
# Va até o diretorio que contem os arquivos da aula ->  shift+clique direito -> open command window here -> jupyter notebook .
#
# ou
#
# Abra o menu iniciar, escolha o executavel jupyter.
#
# ## Linux/Mac
#
# abra o terminal -> va até o diretorio que contem os arquivos do curso -> jupyter notebook .
#
# ## Após abrir o jupyter notebook
#
# Um browser será aberto com o jupyter rodando. Nele você verá todos os arquivos do curso (se não estiver vendo, verá as pastas. Para iniciar a instalaçao dos pacotes abra o arquivo instalacao.ipynb que sera igual a essa pagina html onde você esta vendo essas informaçoes porém com possibilidade de execuçao. Execute as células abaixo que se encarregarão de instalar e configurar os pacotes.

# %%
# !conda install -y --file requirements.txt
#pip install -r requirements_pip.txt # Utilizar essa linha caso a instalação nao seja anaconda
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /home/cadu/anaconda3/envs/ml_ruy:
# #
# ipykernel                 4.6.1                    py36_0    conda-forge
# ipython                   5.3.0                    py36_0    conda-forge
# ipython_genutils          0.2.0                    py36_0    conda-forge
# ipywidgets                6.0.0                    py36_0    conda-forge
# jupyter                   1.0.0                    py36_3
# jupyter_client            5.0.1                    py36_0    conda-forge
# jupyter_console           5.1.0                    py36_0    conda-forge
# jupyter_contrib_core      0.3.1                    py36_0    conda-forge
# jupyter_contrib_nbextensions 0.2.8                    py36_1    conda-forge
# jupyter_core              4.3.0                    py36_0    conda-forge
# ...

# %%
# !jupyter contrib nbextension install --user
# Out:
# [I 06:51:40 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 06:51:40 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 06:51:40 InstallContribNbextensionsApp] Installing /home/cadu/anaconda3/envs/ml_ruy/lib/python3.6/site-packages/jupyter_contrib_nbextensions/nbextensions/contrib_nbextensions_help_item -> contrib_nbextensions_help_item
# [I 06:51:40 InstallContribNbextensionsApp] Up to date: /home/cadu/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/main.js
# [I 06:51:40 InstallContribNbextensionsApp] Up to date: /home/cadu/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/contrib_nbextensions_help_item.yaml
# [I 06:51:40 InstallContribNbextensionsApp] Up to date: /home/cadu/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/README.md
# [I 06:51:40 InstallContribNbextensionsApp] - Validating: OK
# ...
